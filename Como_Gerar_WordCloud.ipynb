# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurMarchiDS/Portfolio/blob/master/Como_Gerar_WordCloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wordcloud -q # Primeiro instalar a biblioteca

# %%
#Importar todas as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS,ImageColorGenerator

# %%
#Importando o Dataset
df = pd.read_csv('http://dl.dropboxusercontent.com/s/fdzigk974zbx2de/listings.csv?dl=0')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (61,62,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#       id  ... reviews_per_month
# 0  17878  ...              2.13
# 1  25026  ...              2.09
# 2  31560  ...              2.37
# 3  35636  ...              2.29
# 4  35764  ...              2.83
#
# [5 rows x 106 columns]

# %%
#Vamos usar só a coluna Summary, e iremos apagar todos os campos vazios
summary = df.dropna(subset = ['summary'], axis=0) ['summary']

# %%
#Juntando todas as palavras em uma única 'frase'
all_summary = ''.join(s for s in summary)

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(stopwords=stopwords).generate(all_summary)

# %%
#Gerando a imagem final
fig, ax = plt.subplots(figsize=(10,6))
ax.imshow(wordcloud, interpolation='bilinear')

plt.show()

# %%
#Ainda contém algumas stopwords, então vamos atualizar a lista.
stopwords = set(STOPWORDS)
stopwords.update(['da', 'meu', 'em', 'você', 'de', 'ao', 'os'])

# %%
#Alterando a cor de fundo.
wordcloud = WordCloud(stopwords=stopwords, background_color='white').generate(all_summary)

# %%
#Gerando a imagem final
fig, ax = plt.subplots(figsize=(10,6))

ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
plt.show()
